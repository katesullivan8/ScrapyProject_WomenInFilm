# %%
import numpy as np
import pandas as pd

pd.DataFrame(pd.read_csv('movie_data.csv'))
# Out:
#                                            film  \
# 0                                  Broken Arrow
# 1                          The War of the Roses
# 2                                 Arachnophobia
# 3                               Michael Collins
# 4                                       Singles
# 5                                Baby's Day Out
# 6                                     The Lover
# 7     The Cook, the Thief, His Wife & Her Lover
# 8                                    To Die For
# 9                            Heavenly Creatures
# 10                         Sleepless in Seattle
# 11                                     Outbreak
# 12                          Edward Scissorhands
# 13                Robin Hood: Prince of Thieves
# 14                            Life Is Beautiful
# 15                           There Goes My Baby
# 16                        Kai xin gui jing ling
# 17                                       Yin ji
# ...
